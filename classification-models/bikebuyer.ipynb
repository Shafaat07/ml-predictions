# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\shafaat hussain\Desktop\aiml\bikebuyer1.csv')
print(data)
# Out:
#          id Marital Status  Gender  Yearly Income  Children        Education  \
# 0     22711         Single    Male        30000.0         0  Partial College
# 1     13555        Married  Female        40000.0         0  Graduate Degree
# 2     28907            NaN    Male       160000.0         5  Partial College
# 3     25410            NaN  Female        70000.0         2        Bachelors
# 4     15756         Single  Female        70000.0         0      High School
# ...     ...            ...     ...            ...       ...              ...
# 9993  28863        Married  Female        40000.0         0  Partial College
# 9994  28864         Single  Female        40000.0         0  Partial College
# 9995  28865        Married    Male        50000.0         0  Partial College
# 9996  28866         Single    Male        50000.0         0  Partial College
# 9997  28867        Married  Female        50000.0         0  Partial College
#
# ...

# %%
data.shape
# Out:
# (9998, 13)

# %%
data.dtypes
# Out:
# id                    int64
# Marital Status       object
# Gender               object
# Yearly Income       float64
# Children              int64
# Education            object
# Occupation           object
# Home Owner           object
# Cars                  int64
# Commute Distance     object
# Region               object
# Age                   int64
# BikeBuyer            object
# dtype: object

# %%
df=pd.DataFrame(data)
pivot= df.pivot_table(index=['Marital Status'], values=['Yearly Income'], aggfunc='mean')
print(pivot)
# Out:
#                 Yearly Income
# Marital Status
# Married          59843.033510
# Single           51143.253876

# %%
df=pd.DataFrame(data)
pivot= df.pivot_table(index=['Gender'], values=['Yearly Income'], aggfunc='mean')
print(pivot)
# Out:
#         Yearly Income
# Gender
# Female   56096.212897
# Male     56091.976517

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      5112
# Female    4886
# Name: count, dtype: int64

# %%
data['Region'].value_counts()
# Out:
# Region
# North America    5455
# Europe           2928
# Pacific          1615
# Name: count, dtype: int64

# %%
data.apply(lambda x : sum(x.isnull()),axis=0)
# Out:
# id                  0
# Marital Status      4
# Gender              0
# Yearly Income       3
# Children            0
# Education           0
# Occupation          0
# Home Owner          0
# Cars                0
# Commute Distance    0
# Region              0
# Age                 0
# BikeBuyer           0
# dtype: int64

# %%
data['Marital Status'].value_counts()
# Out:
# Marital Status
# Married    5670
# Single     4324
# Name: count, dtype: int64

# %%
data['Marital Status'].fillna('Married', inplace=True)

# %%
data['Marital Status'].value_counts()
# Out:
# Marital Status
# Married    5674
# Single     4324
# Name: count, dtype: int64

# %%
data.dtypes
# Out:
# id                    int64
# Marital Status       object
# Gender               object
# Yearly Income       float64
# Children              int64
# Education            object
# Occupation           object
# Home Owner           object
# Cars                  int64
# Commute Distance     object
# Region               object
# Age                   int64
# BikeBuyer            object
# dtype: object

# %%
data.drop(columns=['id'])
# Out:
#      Marital Status  Gender  Yearly Income  Children        Education  \
# 0            Single    Male        30000.0         0  Partial College
# 1           Married  Female        40000.0         0  Graduate Degree
# 2           Married    Male       160000.0         5  Partial College
# 3           Married  Female        70000.0         2        Bachelors
# 4            Single  Female        70000.0         0      High School
# ...             ...     ...            ...       ...              ...
# 9993        Married  Female        40000.0         0  Partial College
# 9994         Single  Female        40000.0         0  Partial College
# 9995        Married    Male        50000.0         0  Partial College
# 9996         Single    Male        50000.0         0  Partial College
# 9997        Married  Female        50000.0         0  Partial College
#
#           Occupation Home Owner  Cars Commute Distance  Region  Age BikeBuyer
# ...

# %%
features=data.iloc[:,:-1].values
features
# Out:
# array([[22711, 'Single', 'Male', ..., '0-1 Miles', 'Europe', 33],
#        [13555, 'Married', 'Female', ..., '0-1 Miles', 'Europe', 37],
#        [28907, 'Married', 'Male', ..., '10+ Miles', 'Europe', 55],
#        ...,
#        [28865, 'Married', 'Male', ..., '5-10 Miles', 'North America', 32],
#        [28866, 'Single', 'Male', ..., '5-10 Miles', 'North America', 32],
#        [28867, 'Married', 'Female', ..., '5-10 Miles', 'North America',
#         32]], dtype=object)

# %%
from sklearn.impute import SimpleImputer
si=SimpleImputer(missing_values=np.nan,strategy='mean')
si.fit(features[:,[3,4,8,11]])
features[:,[3,4,8,11]]=si.fit_transform(features[:,[3,4,8,11]])
x1=pd.DataFrame(features)
print(x1)
# Out:
#          0        1       2         3    4                5               6   \
# 0     22711   Single    Male   30000.0  0.0  Partial College        Clerical
# 1     13555  Married  Female   40000.0  0.0  Graduate Degree        Clerical
# 2     28907  Married    Male  160000.0  5.0  Partial College    Professional
# 3     25410  Married  Female   70000.0  2.0        Bachelors  Skilled Manual
# 4     15756   Single  Female   70000.0  0.0      High School    Professional
# ...     ...      ...     ...       ...  ...              ...             ...
# 9993  28863  Married  Female   40000.0  0.0  Partial College  Skilled Manual
# 9994  28864   Single  Female   40000.0  0.0  Partial College  Skilled Manual
# 9995  28865  Married    Male   50000.0  0.0  Partial College  Skilled Manual
# 9996  28866   Single    Male   50000.0  0.0  Partial College  Skilled Manual
# 9997  28867  Married  Female   50000.0  0.0  Partial College  Skilled Manual
#
# ...

# %%
#Label Encoding

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

data['Region']=le.fit_transform(data['Region'])
